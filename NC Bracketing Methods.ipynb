# %% [markdown]
# <center><h1>Name: Asad haroon</h1><center>

# %% [markdown]
# <center><h1>Bracketing Methods Numerical Computations</h1><center>

# %%
xl=float(input("Enter the value of xl"))
xu=int(input("Enter the value of xu"))
ea=100
li=[]
iteration=1
li.append(xl)
li.append(xu)
def eq(xb):
    x=xb
    import numpy as np
    import math
    radian = xb-np.deg2rad(math.degrees(math.cos(xb)))
    eqq=radian
    return eqq
def s(xl,xu):
    fxl=eq(xl)
    fxu=eq(xu)
    if (fxl*fxu)<0:
        return True
    else:
        return False
es = int(input("Enter the value of es"))
while ea >= es:
    print('xl is {} and xu is {} and it is {}'.format(xl, xu, iteration))
    if iteration == 1:
        if s(xl, xu) == True:
            xr = round(xu- (eq(xu)*(xl-xu))/(eq(xl)-eq(xu)), 6)
            fxl = round(eq(xl), 6)
            fxr = round(eq(xr), 6)
            if (fxl * fxr) < 0:
                print("On iteration {}. Root Lies in lower subinterval. Therefore xu=xr={}.".format(iteration, xr))
                xu = xr
                li.append(xu)
                print("Updated sub-interval is [{},{}]".format(xl, xu))

            elif (fxl * fxr) > 0:
                print("On iteration {}. Root Lies in upper subinterval. Therefore xl=xr={}.".format(iteration, xr))
                xl = xr
                li.append(xl)
                print("Updated sub-interval is [{},{}]".format(xl, xu))

            elif (fxl * fxr) == 0:
                print("Root Found and root is {}".format(xr))
    else:
        xr =round(xu- (eq(xu)*(xl-xu))/(eq(xl)-eq(xu)), 6)
        fxl = round(eq(xl), 6)
        fxr = round(eq(xr), 6)
        if (fxl * fxr) < 0:
            print("On iteration {}. Root Lies in lower subinterval. Therefore xu=xr={}.".format(iteration, xr))
            print('li -1 is '+str(li[-1]))
            ea = round(abs(xr - li[-1]) / abs(xr) * 100, 2)
            #Step 3
            xu = xr
            print("Updated sub-interval is [{},{}]".format(xl, xu))
            li.append(xu)
            print("%age Ea is {}".format(ea))
        elif (fxl * fxr) > 0:
            print("On iteration {}. Root Lies in upper subinterval. Therefore xl=xr={}.".format(iteration, xr))
            ea = round(abs(xr - li[-1]) / abs(xr) * 100, 2)
            xl = xr
            print("Updated sub-interval is [{},{}]".format(xl, xu))
            li.append(xl)
            print("%age Ea is {}".format(ea))
        elif (fxl * fxr) == 0:
            print("Root Found and root is {}".format(xr))
    iteration = iteration + 1
# Out:
# Enter the value of xl0
# Enter the value of xu10
# Enter the value of es1
# xl is 0.0 and xu is 10 and it is 1
# On iteration 1. Root Lies in lower subinterval. Therefore xu=xr=0.844661.
# Updated sub-interval is [0.0,0.844661]
# xl is 0.0 and xu is 0.844661 and it is 2
# On iteration 2. Root Lies in upper subinterval. Therefore xl=xr=0.715404.
# Updated sub-interval is [0.715404,0.844661]
# %age Ea is 18.07
# xl is 0.715404 and xu is 0.844661 and it is 3
# On iteration 3. Root Lies in upper subinterval. Therefore xl=xr=0.738556.
# Updated sub-interval is [0.738556,0.844661]
# %age Ea is 3.13
# xl is 0.738556 and xu is 0.844661 and it is 4
# On iteration 4. Root Lies in upper subinterval. Therefore xl=xr=0.739073.
# Updated sub-interval is [0.739073,0.844661]
# %age Ea is 0.07

# %%
xl=float(input("Enter the value of xl"))
xu=int(input("Enter the value of xu"))
ea=100
li=[]
iteration=1
li.append(xl)
li.append(xu)
def eq(xb):
    x=xb
    import numpy as np
    import math
    radian = x**3-26
    eqq=radian
    return eqq
def s(xl,xu):
    fxl=eq(xl)
    fxu=eq(xu)
    if (fxl*fxu)<0:
        return True
    else:
        return False
es = int(input("Enter the value of es"))
while ea >= es:
    print('xl is {} and xu is {} and it is {}'.format(xl, xu, iteration))
    if iteration == 1:
        print(s(xl, xu))
        if s(xl, xu) == True:
            xr = round((xl + xu) / 2, 6)
            fxl = round(eq(xl), 6)
            fxr = round(eq(xr), 6)
            if (fxl * fxr) < 0:
                print("On iteration {}. Root Lies in lower subinterval. Therefore xu=xr={}.".format(iteration, xr))
                xu = xr
                li.append(xu)
                print("Updated sub-interval is [{},{}]".format(xl, xu))

            elif (fxl * fxr) > 0:
                print("On iteration {}. Root Lies in upper subinterval. Therefore xl=xr={}.".format(iteration, xr))
                xl = xr
                li.append(xl)
                print("Updated sub-interval is [{},{}]".format(xl, xu))

            elif (fxl * fxr) == 0:
                print("Root Found and root is {}".format(xr))
    else:
        xr = round((xl + xu) / 2, 6)
        fxl = round(eq(xl), 6)
        fxr = round(eq(xr), 6)
        if (fxl * fxr) < 0:
            print("On iteration {}. Root Lies in lower subinterval. Therefore xu=xr={}.".format(iteration, xr))
            xu = xr

            print("Updated sub-interval is [{},{}]".format(xl, xu))

            ea = round(abs(xu - li[-1]) / abs(xu) * 100, 2)
            li.append(xu)
            print("%age Ea is {}".format(ea))
        elif (fxl * fxr) > 0:
            print("On iteration {}. Root Lies in upper subinterval. Therefore xl=xr={}.".format(iteration, xr))
            xl = xr

            print("Updated sub-interval is [{},{}]".format(xl, xu))

            ea = round(abs(xl - li[-1]) / abs(xl) * 100, 2)
            li.append(xl)
            print("%age Ea is {}".format(ea))
        elif (fxl * fxr) == 0:
            print("Root Found and root is {}".format(xr))
    iteration = iteration + 1
# Out:
# Enter the value of xl0
# Enter the value of xu10
# Enter the value of es1
# xl is 0.0 and xu is 10 and it is 1
# True
# On iteration 1. Root Lies in lower subinterval. Therefore xu=xr=5.0.
# Updated sub-interval is [0.0,5.0]
# xl is 0.0 and xu is 5.0 and it is 2
# On iteration 2. Root Lies in upper subinterval. Therefore xl=xr=2.5.
# Updated sub-interval is [2.5,5.0]
# %age Ea is 100.0
# xl is 2.5 and xu is 5.0 and it is 3
# On iteration 3. Root Lies in lower subinterval. Therefore xu=xr=3.75.
# Updated sub-interval is [2.5,3.75]
# %age Ea is 33.33
# xl is 2.5 and xu is 3.75 and it is 4
# On iteration 4. Root Lies in lower subinterval. Therefore xu=xr=3.125.
# Updated sub-interval is [2.5,3.125]
# %age Ea is 20.0
# xl is 2.5 and xu is 3.125 and it is 5
# On iteration 5. Root Lies in upper subinterval. Therefore xl=xr=2.8125.
# Updated sub-interval is [2.8125,3.125]
# %age Ea is 11.11
# xl is 2.8125 and xu is 3.125 and it is 6
# On iteration 6. Root Lies in lower subinterval. Therefore xu=xr=2.96875.
# Updated sub-interval is [2.8125,2.96875]
# %age Ea is 5.26
# xl is 2.8125 and xu is 2.96875 and it is 7
# On iteration 7. Root Lies in upper subinterval. Therefore xl=xr=2.890625.
# Updated sub-interval is [2.890625,2.96875]
# %age Ea is 2.7
# xl is 2.890625 and xu is 2.96875 and it is 8
# On iteration 8. Root Lies in upper subinterval. Therefore xl=xr=2.929688.
# Updated sub-interval is [2.929688,2.96875]
# %age Ea is 1.33
# xl is 2.929688 and xu is 2.96875 and it is 9
# On iteration 9. Root Lies in upper subinterval. Therefore xl=xr=2.949219.
# Updated sub-interval is [2.949219,2.96875]
# %age Ea is 0.66
